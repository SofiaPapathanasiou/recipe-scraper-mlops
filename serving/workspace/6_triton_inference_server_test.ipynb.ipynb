# %% [markdown]
# When making any changes to the `config.pbtxt` file:
#
# ```sudo docker compose -f docker-compose-triton.yaml up -d --force-recreate init-models```
#
# ``` sudo docker compose -f docker-compose-triton.yaml up -d --force-recreate triton```

# %%
# runs inside the Jupyter container on node-serve-system
# !perf_analyzer -u triton_server:8000  -m recipe_model  --input-data input.json -b 1
# Out:
#  Successfully read data for 1 stream/streams with 1 step/steps.
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Using synchronous calls for inference
#
# Request concurrency: 1
#   Client:
#     Request count: 21
#     Throughput: 1.16642 infer/sec
#     Avg latency: 840353 usec (standard deviation 13775 usec)
#     p50 latency: 838452 usec
#     p90 latency: 852960 usec
#     p95 latency: 853344 usec
#     p99 latency: 876256 usec
#     Avg HTTP time: 840349 usec (send/recv 90 usec + response wait 840259 usec)
#   Server:
#     Inference count: 21
#     Execution count: 21
#     Successful request count: 21
#     Avg request latency: 840027 usec (overhead 3 usec + queue 33 usec + compute input 42 usec + compute infer 839870 usec + compute output 78 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
# !perf_analyzer -u triton_server:8000  -m recipe_model  --input-data input.json -b 1 --concurrency-range 8
# Out:
#  Successfully read data for 1 stream/streams with 1 step/steps.
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Using synchronous calls for inference
#
# Request concurrency: 8
#   Client:
#     Request count: 83
#     Throughput: 4.60999 infer/sec
#     Avg latency: 1654193 usec (standard deviation 178719 usec)
#     p50 latency: 1694708 usec
#     p90 latency: 1722842 usec
#     p95 latency: 1730441 usec
#     p99 latency: 1734064 usec
#     Avg HTTP time: 1654187 usec (send/recv 428 usec + response wait 1653759 usec)
#   Server:
#     Inference count: 83
#     Execution count: 83
#     Successful request count: 83
#     Avg request latency: 1653491 usec (overhead 3 usec + queue 806168 usec + compute input 34 usec + compute infer 847227 usec + compute output 59 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
# !perf_analyzer -u triton_server:8000  -m recipe_model  --input-data input.json -b 1 --concurrency-range 16
# Out:
#  Successfully read data for 1 stream/streams with 1 step/steps.
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Using synchronous calls for inference
#
# Request concurrency: 16
#   Client:
#     Request count: 84
#     Throughput: 4.66549 infer/sec
#     Avg latency: 3383213 usec (standard deviation 37495 usec)
#     p50 latency: 3390732 usec
#     p90 latency: 3425764 usec
#     p95 latency: 3427242 usec
#     p99 latency: 3431581 usec
#     Avg HTTP time: 3383206 usec (send/recv 146 usec + response wait 3383060 usec)
#   Server:
#     Inference count: 84
#     Execution count: 84
#     Successful request count: 84
#     Avg request latency: 3382817 usec (overhead 3 usec + queue 2537073 usec + compute input 36 usec + compute infer 845642 usec + compute output 61 usec)
# ...

# %%
# runs inside the Jupyter container on node-serve-system
# !perf_analyzer -u triton_server:8000  -m recipe_model  --input-data input.json -b 16 --concurrency-range 1
# Out:
#  Successfully read data for 1 stream/streams with 1 step/steps.
# *** Measurement Settings ***
#   Batch size: 16
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Using synchronous calls for inference
#
# Request concurrency: 1
#   Client:
#     Request count: 21
#     Throughput: 18.6619 infer/sec
#     Avg latency: 872649 usec (standard deviation 72783 usec)
#     p50 latency: 850481 usec
#     p90 latency: 1038495 usec
#     p95 latency: 1039050 usec
#     p99 latency: 1054091 usec
#     Avg HTTP time: 872642 usec (send/recv 150 usec + response wait 872492 usec)
#   Server:
#     Inference count: 336
#     Execution count: 21
#     Successful request count: 21
#     Avg request latency: 872158 usec (overhead 3 usec + queue 47 usec + compute input 49 usec + compute infer 871978 usec + compute output 79 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
# !perf_analyzer -u triton_server:8000  -m recipe_model  --input-data input.json -b 16 --concurrency-range 8
# Out:
#  Successfully read data for 1 stream/streams with 1 step/steps.
# *** Measurement Settings ***
#   Batch size: 16
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average latency and throughput
#   Measurement window: 5000 msec
#   Using synchronous calls for inference
#
# Request concurrency: 8
#   Client:
#     Request count: 82
#     Throughput: 72.869 infer/sec
#     Avg latency: 1776435 usec (standard deviation 103315 usec)
#     p50 latency: 1740990 usec
#     p90 latency: 1931353 usec
#     p95 latency: 2013020 usec
#     p99 latency: 2138113 usec
#     Avg HTTP time: 1776428 usec (send/recv 157 usec + response wait 1776271 usec)
#   Server:
#     Inference count: 1312
#     Execution count: 82
#     Successful request count: 82
#     Avg request latency: 1775908 usec (overhead 3 usec + queue 887542 usec + compute input 43 usec + compute infer 888247 usec + compute output 72 usec)
# ...
